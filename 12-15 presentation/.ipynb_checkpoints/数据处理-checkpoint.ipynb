# %% [markdown]
# # 导入包

# %%
from collections import defaultdict
from tqdm import tqdm
import re
import json
from copy import deepcopy
import random

# %% [markdown]
# # 将数据处理成QA对形式

# %% [markdown]
# ## 读取原始数据

# %%
data_path='/home/xhsun/Desktop/KG/nlpcc2018/nlpcc2018.kbqg.train'
with open(data_path) as f:
    lines=f.readlines()

data=[[]]
for line in lines:
    if len(line.strip().split())<=1:
        data.append([])
    else:
        data[-1].append(line.strip())
if data[-1]==[]:
    del data[-1]
for example in data:
    assert len(example)==2

# %%
print("原始数据有{}个样本".format(len(data)))
print('每一个样本包含（问题，三元组）：')
for i in range(5):
    print("问题：",data[i][1],' 三元组：',data[i][0])
# Out:
# 原始数据有24479个样本
# 每一个样本包含（问题，三元组）：
# 问题： <question id=1>	《机械设计基础》这本书的作者是谁？  三元组： <triple id=1>	机械设计基础 ||| 作者 ||| 杨可桢，程光蕴，李仲生
# 问题： <question id=2>	《高等数学》是哪个出版社出版的？  三元组： <triple id=2>	高等数学 ||| 出版社 ||| 武汉大学出版社
# 问题： <question id=3>	《线性代数》这本书的出版时间是什么？  三元组： <triple id=3>	线性代数 ||| 出版时间 ||| 2013-12-30
# 问题： <question id=4>	安德烈是哪个国家的人呢？  三元组： <triple id=4>	安德烈 ||| 国籍 ||| 摩纳哥
# 问题： <question id=5>	《线性代数》的isbn码是什么？  三元组： <triple id=5>	线性代数 ||| isbn ||| 978-7-111-36843-4

# %% [markdown]
# ## 将原始数据转换为QA对的形式

# %%
all_examples=[]
for example in data:
    triplet,question=example
    triplet=triplet.split('\t')
    question=question.split('\t')
    assert len(question)==2 and question[0].startswith('<') and question[0].endswith('>') and len(triplet)==2
    question=question[1]
    triplet=triplet[1].split('|||')
    assert len(triplet)==3
    entity=triplet[0].strip()
    rel=triplet[1].strip()
    ans=triplet[2].strip()
    assert type(question)==str
    question=question.strip()
    if ('《' in question and '》' in question) and ('《' not in entity and '》' not in entity):
        #print(question,entity)
        entity='《'+entity+'》'
            
    if entity in question:
        start_id=question.find(entity)
        end_id=start_id+len(entity)
        question=question[:start_id]+'<'+entity+'>'+question[end_id:]
        all_examples.append({"question":question,'topic_entity':entity,'answer':ans,'relation':rel})

# %%
print('转换后的每一个样本形如：')
for i in range(5):
    print(all_examples[i])
# Out:
# 转换后的每一个样本形如：
# {'question': '<《机械设计基础》>这本书的作者是谁？', 'topic_entity': '《机械设计基础》', 'answer': '杨可桢，程光蕴，李仲生', 'relation': '作者'}
# {'question': '<《高等数学》>是哪个出版社出版的？', 'topic_entity': '《高等数学》', 'answer': '武汉大学出版社', 'relation': '出版社'}
# {'question': '<《线性代数》>这本书的出版时间是什么？', 'topic_entity': '《线性代数》', 'answer': '2013-12-30', 'relation': '出版时间'}
# {'question': '<安德烈>是哪个国家的人呢？', 'topic_entity': '安德烈', 'answer': '摩纳哥', 'relation': '国籍'}
# {'question': '<《线性代数》>的isbn码是什么？', 'topic_entity': '《线性代数》', 'answer': '978-7-111-36843-4', 'relation': 'isbn'}

# %% [markdown]
# **问题中的实体(topic entity)用<>括起来**

# %% [markdown]
# # 根据构造的QA对数据来提取一个小规模的知识图谱

# %% [markdown]
# ## 首先读取大规模的知识图谱

# %%
sub_map = defaultdict(list)
obj_map = defaultdict(list)
so_map=defaultdict(list)
kg_path='/home/xhsun/Desktop/KG/nlpcc2018/knowledge/original_knowledge/nlpcc-iccpol-2016.kbqa.kb'
with open(kg_path) as f:
    lines=f.readlines()
    
entities_set=set()
relations_set=set()
for i in tqdm(range(len(lines))):
    line=lines[i]
    l = line.strip().split('|||')
    s = l[0].strip()
    p = l[1].strip()
    o = l[2].strip()
    entities_set.add(s)
    entities_set.add(o)
    relations_set.add(p)
    
    sub_map[s].append((p, o))
    obj_map[o].append((s, p))
    so_map[(s,o)].append(p)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████| 43063796/43063796 [02:43<00:00, 263123.08it/s]

# %%
print('大规模图谱中一共有{}个三元组，{}个实体，{}个关系'.format(len(lines),len(entities_set),len(relations_set)))
# Out:
# 大规模图谱中一共有43063796个三元组，16196206个实体，595941个关系

# %% [markdown]
# **sub_map记录的是每一个头实体(subject、head)对应的所有可能出现的(关系,尾实体)的集合**

# %%
sub_map['笑傲江湖']
# Out:
# [('别名', '笑傲江湖'),
#  ('中文名', '笑傲江湖'),
#  ('出品时间', '1990年'),
#  ('制片地区', '中国香港'),
#  ('类型', '喜剧，动作，剧情，爱情'),
#  ('片长', '120分钟'),
#  ('对白语言', '粤语'),
#  ('执行导演', '徐克，程小东，李惠民'),
#  ('外文名', 'Swordsman'),
#  ('出品公司', '金公主电影，新宝娱乐，龙祥影业'),
#  ('导演', '胡金铨'),
#  ('主演', '许冠杰，叶童，张学友，张敏，袁洁莹，刘兆铭'),
#  ('上映时间', '1990年4月5日（中国香港）'),
#  ('色彩', '彩色'),
#  ('书名', '笑傲江湖'),
#  ('作者', '金庸'),
#  ('首播平台', '湖南卫视：金鹰独播剧场'),
#  ('杀青时间', '2012年07月14日'),
#  ('网络首播', '爱奇艺、腾讯、乐视'),
#  ('编剧', '于正'),
#  ('集数', '42集（剪辑版56集）'),
#  ('开机时间', '2012年03月24日'),
#  ('拍摄地点', '浙江省丽水市缙云仙都旅游胜地'),
#  ('影片名称', '笑傲江湖'),
#  ('其他名称', '新加坡版笑傲江湖'),
#  ('香港首播', '2003年02月10日，翡翠台'),
#  ('制片人', '张纪中'),
#  ('其它译名', 'The Proud Youth'),
#  ('制作人', '杨佩佩'),
#  ('游戏类别', '3D武侠网游、MMORPG'),
#  ('游戏语言', '简体中文'),
#  ('发行商', '完美世界'),
#  ('战斗方式', '即时战斗'),
#  ('游戏平台', 'PC、网络游戏'),
#  ('开发商', '完美世界'),
#  ('发行时间', '2013年4月17日'),
#  ('简称', '笑傲江湖'),
#  ('中文名称', '《笑傲江湖》'),
#  ('播出时间', '2014年3月16日首播'),
#  ('语言', '汉语普通话'),
#  ('嘉宾', '冯小刚、宋丹丹、吴君如、刘仪伟'),
#  ('书籍封面', '书籍封面'),
#  ('出版地', '香港'),
#  ('题材', '武侠'),
#  ('出版者', '明河社（香港） 远流（台湾） 牛津大学出版社 英语译本 德间书店 日语译本'),
#  ('出版日期', '1967年'),
#  ('媒介', '纸本'),
#  ('开本', '平装'),
#  ('上一部作品', '侠客行'),
#  ('下一部作品', '鹿鼎记')]

# %% [markdown]
# **obj_map记录的是每一个尾实体(object、tail)对应的所有可能出现的(头实体，关系)的集合**

# %%
obj_map['金庸']
# Out:
# [('阿丽丝漫游记', '作者'),
#  ('雪山飞狐(吕良伟1985年主演电视剧)', '原著'),
#  ('汤沛', '作者'),
#  ('日月神教', '撰写者'),
#  ('射雕英雄传(金庸武侠小说)', '作者'),
#  ('侯通海', '作者'),
#  ('袁冠南', '作者'),
#  ('袁崇焕评传', '作者'),
#  ('江南七怪', '作者'),
#  ('程灵素', '作者'),
#  ('射雕英雄传之东成西就', '故事'),
#  ('计无施', '小说作者'),
#  ('郭芙', '作者'),
#  ('冯锡范', '作者'),
#  ('风清扬', '作者'),
#  ('达尔巴', '作者'),
#  ('金庸全集', '作者'),
#  ('阿珂', '作者'),
#  ('射雕英雄传(2003年内地版李亚鹏、周迅主演电视剧)', '原著'),
#  ('王语嫣', '作者'),
#  ('辟邪剑谱', '作者'),
#  ('辟邪剑谱', '作 者'),
#  ('定静师太', '作者'),
#  ('丹青生', '作者'),
#  ('独孤九剑(金庸小说中的武学)', '作者'),
#  ('嵩山十三太保', '作者'),
#  ('嵩山十三太保', '作 者'),
#  ('花万紫', '作品作者'),
#  ('雪山飞狐(金庸武侠小说)', '作者'),
#  ('冰雪儿', '作者'),
#  ('骆冰', '作者'),
#  ('钟灵', '作者'),
#  ('天山六阳掌', '作者'),
#  ('天山六阳掌', '作 者'),
#  ('碧血剑(1956年金庸创作武侠小说)', '作者'),
#  ('焦宛儿', '作者'),
#  ('木婉清', '作者'),
#  ('内劲', '较早提出者'),
#  ('倚天屠龙记(武侠小说改编漫画)', '原作'),
#  ('白阿绣', '作者'),
#  ('笑傲江湖(金庸创作小说)', '作者'),
#  ('徐潮生', '作者'),
#  ('连城诀(金庸创作武侠小说)', '作者'),
#  ('胡青牛', '作者'),
#  ('胡青牛', '作 者'),
#  ('书剑恩仇录(1976年香港TVB郑少秋主演版电视剧)', '原著'),
#  ('上官剑南', '作者'),
#  ('雪山飞狐(聂远2007年主演电视剧)', '原著'),
#  ('金庸作品', '作者'),
#  ('五轮大转', '作者'),
#  ('雪山飞狐(卫子云1978年主演电视剧)', '原著'),
#  ('平阿四', '作者'),
#  ('小鸽子姑娘', '编剧'),
#  ('朱子柳', '作者'),
#  ('金庸散文集', '作者'),
#  ('商剑鸣', '作者'),
#  ('焦公礼', '作者'),
#  ('射雕三部曲', '作者'),
#  ('童百熊', '饰演'),
#  ('文泰来', '作者'),
#  ('胡桂南', '原作者'),
#  ('兰花花(1958年香港电影)', '编剧'),
#  ('五散人', '作者'),
#  ('五散人', '作 者'),
#  ('庄聚贤', '作者'),
#  ('金庸小说', '作者'),
#  ('金庸小说', '小说类型'),
#  ('胡青羊', '作者'),
#  ('天龙八部(金庸创作小说)', '作者'),
#  ('书剑恩仇录(金庸创作武侠小说)', '作者'),
#  ('杨过', '作者'),
#  ('黑白子', '作者'),
#  ('听香水榭', '作者'),
#  ('四大恶人(金庸小说人物组合)', '原创作者'),
#  ('参合指', '作家'),
#  ('参合指', '作 家'),
#  ('金庸作品集全集', '作者'),
#  ('成不忧', '作者'),
#  ('苏鲁克', '小说作者'),
#  ('程青竹', '作者'),
#  ('苗若兰', '作者'),
#  ('月云', '类型'),
#  ('明窗小札1963', '作者'),
#  ('冯难敌', '作者'),
#  ('慧风', '作者'),
#  ('孤独求败', '作者'),
#  ('恒山三定', '登场作品作者'),
#  ('白马啸西风', '作者'),
#  ('白马啸西风', '作 者'),
#  ('摘星子', '作者'),
#  ('温青青', '作者'),
#  ('郭靖(金庸武侠小说《射雕英雄传》男主角)', '作者'),
#  ('玄苦', '小说作者'),
#  ('金庸', '别名'),
#  ('金庸', '别 名'),
#  ('穆念慈', '作者'),
#  ('鸳鸯刀(金庸创作武侠小说)', '作者'),
#  ('射雕英雄传(1983年黄日华、翁美玲主演电视剧)', '原著'),
#  ('思过崖', '出自'),
#  ('林远图', '作者'),
#  ('飞雪连天射白鹿', '原作者'),
#  ('大粽子', '作者'),
#  ('秦红棉', '作者'),
#  ('落英剑法', '作者'),
#  ('金庸奇侠', '原作'),
#  ('冰魄银针毒', '作者'),
#  ('躺尸剑法', '作者'),
#  ('独孤九剑(网络游戏)', '作者'),
#  ('书剑恩仇录(1981年香港邵氏狄龙主演版电影)', '编剧'),
#  ('司徒伯雷', '作者名'),
#  ('赵钱孙', '创造者'),
#  ('江南四友', '作者'),
#  ('苏荃', '作者'),
#  ('灭绝师太', '作者'),
#  ('释迦掷象功', '作者'),
#  ('封不平', '作者'),
#  ('桃花(王家卫导演的电影《东邪西毒》中的人物)', '原著'),
#  ('冯蘅', '作者'),
#  ('罗立如', '作者'),
#  ('马大元', '作者'),
#  ('明教四大法王', '作者'),
#  ('七虫七花膏', '发明者'),
#  ('灵蛇拳', '作者'),
#  ('桃谷六仙', '作者'),
#  ('桃谷六仙', '作 者'),
#  ('欧阳峰', '作者'),
#  ('左子穆', '作者'),
#  ('定逸', '作者'),
#  ('萧中慧', '作者'),
#  ('碧血剑(2007年窦智孔、黄圣依主演电视剧)', '作者'),
#  ('神照上人', '作者'),
#  ('夫妻刀法', '作者'),
#  ('神雕侠侣', '原著'),
#  ('神雕侠侣', '原作者'),
#  ('神雕侠侣', '作者'),
#  ('神雕侠侣', '原著作者'),
#  ('连城诀(2004年大陆版电视剧)', '原著'),
#  ('丘处机之未成诗', '作者'),
#  ('金庸作品集（文库本）', '作者'),
#  ('范百龄', '作者'),
#  ('金庸武侠全集（全36册）（繁体竖排点评本）', '作者'),
#  ('射雕英雄传（7）大字版', '作者'),
#  ('俞连舟', '作者'),
#  ('査传侠', '父亲'),
#  ('少年游·本意', '作者'),
#  ('碧血剑(1977年香港佳视出品电视剧)', '原著'),
#  ('天龙八部(2013年钟汉良版电视剧)', '原著'),
#  ('关明梅', '作者'),
#  ('无量玉壁', '相关人物'),
#  ('傅思归', '作者'),
#  ('陈达海', '作者'),
#  ('古今五大神功', '作者'),
#  ('舒化龙(小说《鹿鼎记》人物)', '作家'),
#  ('神雕侠侣（全四册）', '作者'),
#  ('天龙八部之六脉神剑、虚竹传奇(1982年TVB电视剧)', '原著'),
#  ('射雕英雄传（全四册）', '作者'),
#  ('侠客行(金庸创作武侠小说)', '作者'),
#  ('东邪西毒', '故事'),
#  ('射雕英雄传(1983年香港TVB版黄日华、翁美玲主演电视剧)', '原著'),
#  ('奇门三才刀', '作者'),
#  ('鹿鼎记(2008年张纪中制片电视剧)', '原著'),
#  ('成高道人', '作者'),
#  ('天龙八部(1997年黄日华版电视剧)', '原著'),
#  ('刘鹤真', '作者'),
#  ('射雕英雄传(1988年台湾中视版黄文豪、陈玉莲主演电视剧)', '原著'),
#  ('天龙八部之六脉神剑、虚竹传奇', '原著'),
#  ('天龙八部之六脉神剑、虚竹传奇', '原作'),
#  ('射雕英雄传(2008年内地版胡歌、林依晨主演电视剧)', '原著'),
#  ('孙小蝶', '作者'),
#  ('荣彩(金庸小说《碧血剑》人物)', '作者'),
#  ('丁游', '作者'),
#  ('群侠传之梦幻金庸', '原作'),
#  ('神雕侠侣(1976年香港佳视版罗乐林、李通明主演电视剧)', '原著'),
#  ('枯荣长老', '塑造人'),
#  ('迟百诚', '作者'),
#  ('药王门', '作者'),
#  ('倚天屠龙记(2001年香港TVB版吴启华主演电视剧)', '原著'),
#  ('圣火令(51wan年度最新横版武侠回合制游戏)', '作者'),
#  ('瓦尔拉齐', '作者'),
#  ('冰蚕掌', '作者'),
#  ('神雕侠侣 1-8 新修文库版', '作者'),
#  ('赠玉如意乾隆', '作者'),
#  ('覃天丞', '作者'),
#  ('玄悲', '作者'),
#  ('东方不败(金庸武侠小说《笑傲江湖》中的人物)', '作者'),
#  ('澄光', '作者'),
#  ('方评', '作者'),
#  ('神雕侠侣(2003年出版的武侠小说改编动画)', '原作'),
#  ('神雕侠侣(2003年出版的武侠小说改编动画)', '原作者'),
#  ('倚天屠龙记(2003年合拍版苏有朋主演电视剧)', '原著'),
#  ('倚天屠龙记(2009年大陆版邓超主演电视剧)', '原著'),
#  ('神雕剣侠金庸武侠小说集 3', '作者'),
#  ('神雕侠侣(1959年出版的金庸武侠小说)', '作者'),
#  ('天山折梅手', '作者'),
#  ('天山折梅手', '作 者'),
#  ('迟玄', '作者'),
#  ('天鹰教', '作者'),
#  ('金庸作品集：书剑恩仇录', '作者'),
#  ('陈正德(金庸小说人物)', '作者'),
#  ('乾隆之锦锈乾坤', '作者'),
#  ('绕指柔剑', '作者'),
#  ('乾坤大挪移(武侠小说中武功名称)', '小说作者'),
#  ('神雕侠侣(2006年内地版黄晓明、刘亦菲主演电视剧)', '原著'),
#  ('飞狐外传(金庸创作小说)', '作者'),
#  ('评点本金庸武侠全集', '作者'),
#  ('枯荣为6定帝剃度所吟', '作者'),
#  ('李傀儡', '创作人'),
#  ('连环庄', '作者'),
#  ('智光大师(《天龙八部》人物)', '作者'),
#  ('掌钵龙头', '作者'),
#  ('三恋', '编剧'),
#  ('陈大方', '作者'),
#  ('金庸作品集：倚天屠龙记', '作者'),
#  ('越女剑(金庸武侠小说)', '作者'),
#  ('金庸作品集（36册）', '作者'),
#  ('神雕侠侣(4)大字版', '作者'),
#  ('射雕英雄传ZERO', '原作'),
#  ('金庸武侠小说全集（电子图书二碟装）', '作者'),
#  ('有女怀春(1958年金庸、程步高联合执导电影)', '编剧'),
#  ('降龙廿八掌', '作者'),
#  ('位面武神', '作家'),
#  ('黑风双煞(《射雕英雄传》里的组合)', '作者'),
#  ('陈七', '作者'),
#  ('倚天屠龙记(金庸经典武侠长篇小说)', '作者'),
#  ('神雕侠侣(1983年香港TVB版刘德华、陈玉莲主演电视剧)', '原著'),
#  ('雪山飞狐(1991年孟飞主演电视剧)', '原著'),
#  ('金刚伏魔神通', '作者'),
#  ('天龙八部(1-5)', '作者'),
#  ('桃花岛主', '作者'),
#  ('逍遥派(词语释义)', '作者'),
#  ('书剑恩仇录(2015张纪中版书剑恩仇录)', '原著'),
#  ('金庸作品集（明河社）', '作者'),
#  ('析雪山飞狐与鸳鸯刀', '作者'),
#  ('风际中', '作者'),
#  ('圣因师太', '作者'),
#  ('邓八公', '作者'),
#  ('洪人雄', '作者'),
#  ('绝代佳人(汉语词语)', '编剧'),
#  ('吴天德(武侠小说《笑傲江湖》中人物)', '作者'),
#  ('史叔刚', '作者'),
#  ('神雕侠侣·8', '作者'),
#  ('董开山', '作者'),
#  ('血鸟(连载版《射雕英雄传》里的生物)', '作者'),
#  ('鹿鼎记(1969年金庸创作武侠小说)', '作者'),
#  ('旧版倚天屠龙记', '作者'),
#  ('赠阮星竹', '作者'),
#  ('香冢之Ⅴ', '作者'),
#  ('电机时代', '作者'),
#  ('史镖头', '作者'),
#  ('天龙八部漫画', '作者'),
#  ('阿诺(现实人物)', '喜欢作家'),
#  ('桑土公', '原著作者'),
#  ('逍遥游拳法', '作者'),
#  ('笑傲江湖（全四册）', '作者'),
#  ('干光豪', '作者'),
#  ('林玉龙', '作者'),
#  ('武林盟主(武侠小说文学代表)', '代指'),
#  ('被逝世', '人物'),
#  ('余人彦', '作者'),
#  ('听香水榭(诗词)', '作者'),
#  ('绝代佳人(1953年李萍倩执导电影)', '编剧'),
#  ('射雕英雄传(2015年陈嘉上指导的电影)', '编剧'),
#  ('曹司朋', '作者'),
#  ('玉如意唱一半儿小曲', '作者'),
#  ('奚三祁', '作者'),
#  ('天竺神僧', '作者'),
#  ('神雕侠侣漫画', '原作名'),
#  ('金庸作品集（新修版）', '作者'),
#  ('天龙八部(1997年黄日华、陈浩民主演电视剧)', '原著'),
#  ('忽悠功夫', '作者'),
#  ('全真七子布天罡北斗所吟', '作者'),
#  ('神雕侠侣 5', '作者'),
#  ('董培新画说金庸', '原著'),
#  ('吴柏英', '创作人'),
#  ('褚圆', '作者'),
#  ('上官毅山', '作者'),
#  ('射雕英雄传(2000年SCEI制作发行游戏)', '原作'),
#  ('齐云璈', '作者'),
#  ('雪山飞狐(金庸创作武侠小说《雪山飞狐》)', '作者'),
#  ('倚天屠龙记（全四册）', '作者'),
#  ('慧通', '作者'),
#  ('慧通', '作 者'),
#  ('天山童姥', '作者'),
#  ('王处一所唱', '作者'),
#  ('射雕英雄传(2017年杨幂主演电影)', '编剧'),
#  ('天龙八部(2013年钟汉良主演电视剧)', '原著'),
#  ('1992版《书剑恩仇录》', '作者'),
#  ('神雕侠侣(1999年出版的武侠小说改编漫画)', '原著'),
#  ('明窗小札1963（下）', '作者'),
#  ('苏冈', '作者'),
#  ('本尘大师', '作者'),
#  ('桃枝仙', '作者'),
#  ('小曲小昭', '作者'),
#  ('灵蛇岛', '作者'),
#  ('杜长老', '作者'),
#  ('枯荣为保定帝剃度所吟', '作者'),
#  ('大佛岩景区', '来源'),
#  ('聋哑头陀', '作者'),
#  ('金庸星', '命名'),
#  ('鹿鼎记', '作者'),
#  ('莫花尔彻', '作者'),
#  ('成璜', '作者'),
#  ('林仲雄', '作者'),
#  ('胖瘦头陀', '作者'),
#  ('神雕侠侣(2006年刘亦菲主演电视剧)', '原著'),
#  ('神雕侠侣(6)大字版', '作者'),
#  ('Happy Baby早教挂图', '作者'),
#  ('赠乾隆陈家洛', '作者'),
#  ('何三七', '作者'),
#  ('宫九佳', '作者'),
#  ('金庸作品集（全一册）', '作者'),
#  ('蓝天和', '作者'),
#  ('射雕英雄传(5)大字版', '作者'),
#  ('灵宝山国家森林公园', '景区相关名人'),
#  ('峨眉钢刺', '作者'),
#  ('红花会(小说中的反清团体)', '作者'),
#  ('枯荣禅功', '作者'),
#  ('关安基', '作者'),
#  ('耿万钟', '作者'),
#  ('杜百当', '作者'),
#  ('点苍双剑', '作者'),
#  ('香冢之题词', '作者'),
#  ('太虚子', '创造人'),
#  ('射雕英雄传(金庸著武侠小说)', '作者'),
#  ('明窗小札1963（上）', '作者'),
#  ('神雕侠侣·6', '作者'),
#  ('程维藩', '作者'),
#  ('《碧血剑》', '编剧'),
#  ('简长老', '作者'),
#  ('《飞狐外传》(小说)', '作者'),
#  ('《雪山飞狐》(小说)', '作者'),
#  ('冯同知', '作者'),
#  ('黄老邪', '作者'),
#  ('对喀纳', '作者'),
#  ('天龙八部', '作者'),
#  ('天龙八部', '原著'),
#  ('天龙八部', '原作者'),
#  ('方证', '作者'),
#  ('《倚天屠龙记》(武侠小说)', '作者'),
#  ('射雕英雄传(小说)', '作者'),
#  ('2006版《鹿鼎记》', '编剧'),
#  ('崔希敏', '作者'),
#  ('《笑傲江湖》(小说)', '作者'),
#  ('《神雕侠侣》(2006年中国电视剧)', '编剧'),
#  ('冯不破', '作者'),
#  ('《神雕侠侣》(1995年中国电视剧)', '编剧'),
#  ('《神雕侠侣》(2001年香港动画片)', '编剧'),
#  ('康敏(金庸武侠小说《天龙八部》中人物)', '作者'),
#  ('范中恩', '作者'),
#  ('《神雕侠侣》(国产电视剧)', '编剧'),
#  ('程英', '作者'),
#  ('方人智', '作者'),
#  ('射雕英雄传', '作者'),
#  ('射雕英雄传', '原著'),
#  ('飞狐外传', '作者'),
#  ('新神雕侠侣(2006年刘亦菲主演电视剧)', '编剧'),
#  ('林朝英', '作者'),
#  ('双儿(双儿金庸武侠小说《鹿鼎记》中的女主角)', '作者'),
#  ('《神雕侠侣》(2005年国产电视剧)', '编剧'),
#  ('《笑傲江湖》(李亚鹏版)', '编剧'),
#  ('方有德', '作者'),
#  ('鸳鸯刀', '作者'),
#  ('《神雕侠侣》(1999年新加坡电视剧)', '编剧'),
#  ('归钟', '作者'),
#  ('《书剑江山》', '作者'),
#  ('崔秋山', '作者'),
#  ('《天龙八部》(1997年香港电视剧)', '编剧'),
#  ('《神雕侠侣》(小说)', '作者'),
#  ('高颜超', '作者'),
#  ('逍遥子', '作者'),
#  ('《金庸作品集》', '作者'),
#  ('独孤求败', '作者'),
#  ('韩文冲', '作者'),
#  ('高师弟', '作者'),
#  ('《神雕侠侣》(2001年中国动画片)', '编剧'),
#  ('《神雕侠侣》(动画片)', '编剧'),
#  ('笑傲江湖', '作者'),
#  ('雪山飞狐', '作者'),
#  ('雪山飞狐', '原著'),
#  ('连城诀', '作者'),
#  ('连城诀', '原著'),
#  ('连城诀', '原作者'),
#  ('碧血剑', '作者'),
#  ('侠客行', '作者'),
#  ('倚天屠龙记', '作者'),
#  ('倚天屠龙记', '原著'),
#  ('射雕英雄传EAGLET', '原作'),
#  ('越女剑', '作者'),
#  ('书剑恩仇录', '原著'),
#  ('书剑恩仇录', '作者'),
#  ('笑傲江湖之东方不败', '原著'),
#  ('新天龙八部', '原著'),
#  ('神雕侠侣(动画)', '原作'),
#  ('天龙八部(1990年电视剧)', '原创'),
#  ('天龙八部(小说)', '作者'),
#  ('笑傲江湖(2013年电视剧)', '原创'),
#  ('射雕英雄传(1977年电影)', '原著'),
#  ('笑傲江湖(漫画)', '原作'),
#  ('射雕英雄传(漫画)', '原作'),
#  ('天龙八部(2013年电视剧)', '原创'),
#  ('东方不败之风云再起', '原著'),
#  ('笑傲江湖(2000年台湾电视剧)', '原创'),
#  ('神雕侠侣(1998年台视电视剧)', '原创'),
#  ('笑傲江湖II东方不败', '故事'),
#  ('笑傲江湖II东方不败', '原著'),
#  ('神雕侠侣(2014年电视剧)', '原创'),
#  ('倚天屠龙记(2003年电视剧)', '原创'),
#  ('射雕英雄传(2003年电视剧)', '原创'),
#  ('神雕侠侣(1998年新加坡电视剧)', '故事')]

# %% [markdown]
# **so_map记录的每一个（头实体，尾实体）对应的所有可能的关系集合**

# %%
print(so_map[('姚明', '226厘米')])
print(so_map[('姚明', '中国')])
# Out:
# ['身高']
# ['国籍']

# %% [markdown]
# ## 根据QA对数据构造小规模知识图谱

# %% [markdown]
# 符号说明
# - KG   知识图谱
# - $T_{big}$  大规模KG中三元组集合
# - $E_{big}$  大规模KG中的实体集合
# - $R_{big}$  大规模KG中的关系集合

# %% [markdown]
# 构造的思路是对于数据集中每一个（问题，答案）：
# 1. 将问题中的topic entity作为头实体，答案视为尾实体，根据（头实体，尾实体）的组合从so_map中找到所有可能的关系。
# 2. 根据问题中的topic entity，获取这个topic entity的n跳路径内的所有实体（n一般设置为2-4即可）

# %% [markdown]
# 第一步的目的是统计QA数据集中每一个（问题，答案）之间的所有关系，记为集合$R_{qa}$，该集合代表的是整个QA数据集中所有可能出现的关系。
# 针对$T_{big}$，我们仅保留涉及这些关系的三元组，**也就是说对于$T_{big}$中的某个三元组$(h,r,t)$，如果$r$不在集合$R_{qa}$中,那么这个三元组就会被舍弃**。
#
# 显然这一步的目的是为了缩小关系集合，从而进一步的缩小三元组数量以及对应的实体数量。
#
# 第二步的目的是通过限定路径长度进一步的缩小实体数量。

# %%
small_triplets=set()
small_entities=set()
small_relations=set()
new_examples=[]
bad_entities=[]
bad_answers=[]
for i in tqdm(range(len(all_examples))):
    example=deepcopy(all_examples[i])
    question,topic_entity,answer,relation=example['question'],example['topic_entity'],example['answer'],example['relation']
    answer=answer.replace('\t','').replace(' ','')
    example['answer']=answer
    if answer.strip()=='':
        continue
    elif topic_entity not in sub_map:
        bad_entities.append(topic_entity)
        continue
    elif answer not in obj_map:
        bad_answers.append(answer)
        continue
    else:
        head=topic_entity
        small_entities.add(head)
        small_entities.add(answer)
        for rel in so_map[(head,answer)]:
            small_relations.add(rel)#仅仅添加qa数据对中涉及的关系即可
        
        for p1, o1 in sub_map[head]:
            if p1 in small_relations:
                small_triplets.add((head,p1,o1))
                small_entities.add(o1)
            for p2, o2 in sub_map[o1]:
                if p2 in small_relations:
                    small_triplets.add((o1,p2,o2))
                    small_entities.add(o2)
                for p3, o3 in sub_map[o2]:
                    if p3 in small_relations:
                        small_triplets.add((o2,p3,o3))
                        small_entities.add(o3)
                    for p4, o4 in sub_map[o3]:
                        if p4 in small_relations:
                            small_triplets.add((o3,p4,o4))
                            small_entities.add(o4)
        new_examples.append(example)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 23999/23999 [00:13<00:00, 1824.77it/s]

# %%
print('大规模图谱中一共有{}个三元组，{}个实体，{}个关系'.format(len(lines),len(entities_set),len(relations_set)))
print('小规模图谱中一共有{}个三元组，{}个实体，{}个关系'.format(len(small_triplets),len(small_entities),len(small_relations)))
# Out:
# 大规模图谱中一共有43063796个三元组，16196206个实体，595941个关系
# 小规模图谱中一共有369812个三元组，190912个实体，3906个关系

# %% [markdown]
# **QA数据集和知识图谱构造完毕**

# %%
new_examples[0]
# Out:
# {'question': '<《机械设计基础》>这本书的作者是谁？',
#  'topic_entity': '《机械设计基础》',
#  'answer': '杨可桢，程光蕴，李仲生',
#  'relation': '作者'}

# %% [markdown]
# # 将QA数据集划分并保存

# %%
random.shuffle(new_examples)

def write_file(data,path):
    f=open(path,'w')
    for example in data:
        question,topic_entity,answer,relation=example['question'],example['topic_entity'],example['answer'],example['relation']
        if answer=='' or answer.strip()=='':
            count+=1
            continue
        f.write(question+'\t'+answer+'\t'+'\n')
    f.close()
    
write_file(new_examples[:-2000],'/home/xhsun/Desktop/KG/QApairs/ChineseQA/train.txt')
write_file(new_examples[-2000:],'/home/xhsun/Desktop/KG/QApairs/ChineseQA/test.txt')

# %% [markdown]
# # 保存构造的小规模知识图谱

# %%
print('小规模图谱中一共有{}个三元组，{}个实体，{}个关系'.format(len(small_triplets),len(small_entities),len(small_relations)))
# Out:
# 小规模图谱中一共有369812个三元组，190912个实体，3906个关系

# %% [markdown]
# ## 保存三元组

# %%
with open("/home/xhsun/Desktop/KG/nlpcc2018/knowledge/small_knowledge/small_kb",'w') as f:
    for head,rel,tail in small_triplets:
        f.write('|||'.join([head,rel,tail])+'\n')

# %% [markdown]
# ## 保存实体

# %%
with open("/home/xhsun/Desktop/KG/nlpcc2018/knowledge/small_knowledge/entities.dict",'w') as f:
    for i,ent in enumerate(small_entities):
        f.write(ent+'\t'+str(i)+'\n')

# %% [markdown]
# ## 保存关系

# %%
with open("/home/xhsun/Desktop/KG/nlpcc2018/knowledge/small_knowledge/relations.dict",'w') as f:
    for i,rel in enumerate(small_relations):
        f.write(rel+'\t'+str(i)+'\n')

# %% [markdown]
# **至此，数据处理部分完毕**
